# %%
 #link dataset : https://drive.google.com/file/d/1-w9tMvlswf1PIxygb7KJ1Bbwy4UI45rx/view?usp=sharing

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !cp /content/drive/MyDrive/ML_ObjectDetectionModelSmall.zip /content/

# %%
import zipfile

with zipfile.ZipFile("/content/ML_ObjectDetectionModelSmall.zip", 'r') as zip_ref:
    zip_ref.extractall("/content/dataset")

# %%
pip install keras-cv
# Out:
# Requirement already satisfied: keras-cv in /usr/local/lib/python3.10/dist-packages (0.9.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from keras-cv) (24.2)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.10/dist-packages (from keras-cv) (1.4.0)
# Requirement already satisfied: regex in /usr/local/lib/python3.10/dist-packages (from keras-cv) (2024.9.11)
# Requirement already satisfied: tensorflow-datasets in /usr/local/lib/python3.10/dist-packages (from keras-cv) (4.9.7)
# Requirement already satisfied: keras-core in /usr/local/lib/python3.10/dist-packages (from keras-cv) (0.1.7)
# Requirement already satisfied: kagglehub in /usr/local/lib/python3.10/dist-packages (from keras-cv) (0.3.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from kagglehub->keras-cv) (2.32.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from kagglehub->keras-cv) (4.66.6)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from keras-core->keras-cv) (1.26.4)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from keras-core->keras-cv) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.10/dist-packages (from keras-core->keras-cv) (0.0.8)
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (from keras-core->keras-cv) (3.12.1)
# Requirement already satisfied: dm-tree in /usr/local/lib/python3.10/dist-packages (from keras-core->keras-cv) (0.1.8)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->keras-cv) (8.1.7)
# Requirement already satisfied: immutabledict in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->keras-cv) (4.2.0)
# Requirement already satisfied: promise in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->keras-cv) (2.3)
# Requirement already satisfied: protobuf>=3.20 in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->keras-cv) (4.25.5)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->keras-cv) (5.9.5)
# Requirement already satisfied: pyarrow in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->keras-cv) (17.0.0)
# Requirement already satisfied: simple-parsing in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->keras-cv) (0.1.6)
# Requirement already satisfied: tensorflow-metadata in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->keras-cv) (1.13.1)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->keras-cv) (2.5.0)
# Requirement already satisfied: toml in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->keras-cv) (0.10.2)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->keras-cv) (1.16.0)
# Requirement already satisfied: array-record>=0.5.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->keras-cv) (0.5.1)
# Requirement already satisfied: etils>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from etils[edc,enp,epath,epy,etree]>=1.6.0; python_version < "3.11"->tensorflow-datasets->keras-cv) (1.10.0)
# Requirement already satisfied: typing_extensions in /usr/local/lib/python3.10/dist-packages (from etils[edc,enp,epath,epy,etree]>=1.6.0; python_version < "3.11"->tensorflow-datasets->keras-cv) (4.12.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from etils[edc,enp,epath,epy,etree]>=1.6.0; python_version < "3.11"->tensorflow-datasets->keras-cv) (2024.10.0)
# Requirement already satisfied: importlib_resources in /usr/local/lib/python3.10/dist-packages (from etils[edc,enp,epath,epy,etree]>=1.6.0; python_version < "3.11"->tensorflow-datasets->keras-cv) (6.4.5)
# Requirement already satisfied: zipp in /usr/local/lib/python3.10/dist-packages (from etils[edc,enp,epath,epy,etree]>=1.6.0; python_version < "3.11"->tensorflow-datasets->keras-cv) (3.21.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->kagglehub->keras-cv) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->kagglehub->keras-cv) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->kagglehub->keras-cv) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->kagglehub->keras-cv) (2024.8.30)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from promise->tensorflow-datasets->keras-cv) (1.16.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras-core->keras-cv) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras-core->keras-cv) (2.18.0)
# Requirement already satisfied: docstring-parser<1.0,>=0.15 in /usr/local/lib/python3.10/dist-packages (from simple-parsing->tensorflow-datasets->keras-cv) (0.16)
# Requirement already satisfied: googleapis-common-protos<2,>=1.52.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow-metadata->tensorflow-datasets->keras-cv) (1.66.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->keras-core->keras-cv) (0.1.2)

# %%
import os
import tensorflow as tf
import numpy as np
import random
from tensorflow import keras
import keras_cv
from sklearn.model_selection import train_test_split

# %%
import os
import tensorflow as tf

# 1. Definisikan Direktori Dataset
image_dir = '/content/dataset/ML_ObjectDetectionModelSmall/data'
train_images_dir = os.path.join(image_dir, 'train')
val_images_dir = os.path.join(image_dir, 'validation')

# 2. Fungsi untuk memeriksa apakah gambar valid
def is_valid_image(image_path):
    try:
        image = tf.io.read_file(image_path)
        tf.image.decode_jpeg(image)  # Ganti dengan decode sesuai format jika perlu
        return True
    except Exception as e:
        print(f"File {image_path} tidak valid: {e}")
        return False

# 3. Fungsi untuk mengonversi gambar ke JPEG
def convert_image_to_jpeg(image_path, target_size=(416, 416)):
    # Membaca file gambar
    image = tf.io.read_file(image_path)

    # Menentukan format gambar asli
    image_format = tf.image.decode_image(image, channels=3, dtype=tf.dtypes.uint8)

    # Jika gambar hanya memiliki 1 channel (grayscale), konversi ke RGB
    if image_format.shape[-1] == 1:
        image_format = tf.image.grayscale_to_rgb(image_format)

    # Mengonversi gambar ke JPEG setelah resize
    image_resized = tf.image.resize(image_format, target_size) / 255.0  # Normalisasi
    image_jpeg = tf.image.encode_jpeg(tf.cast(image_resized * 255.0, tf.uint8))  # Encode ke JPEG

    return image_jpeg

# 4. Fungsi untuk menyimpan gambar hasil konversi ke file JPEG
def save_converted_image(image_jpeg, output_path):
    tf.io.write_file(output_path, image_jpeg)

# 5. Fungsi untuk mengonversi semua gambar di direktori ke format JPEG
def convert_all_images_to_jpeg(image_dir, target_dir, target_size=(416, 416)):
    if not os.path.exists(target_dir):
        os.makedirs(target_dir)

    # Iterasi semua gambar dalam direktori
    for subdir, dirs, files in os.walk(image_dir):
        for file in files:
            if file.lower().endswith(('.jpg', '.jpeg', '.png', '.gif', '.bmp')):  # Semua format gambar
                image_path = os.path.join(subdir, file)

                # Cek apakah gambar valid
                if is_valid_image(image_path):
                    # Menentukan nama file output (ganti ekstensi dengan .jpg)
                    output_filename = file.split('.')[0] + '.jpg'

                    # Membuat subfolder yang sama di target_dir
                    relative_subdir = os.path.relpath(subdir, image_dir)
                    output_subdir = os.path.join(target_dir, relative_subdir)

                    if not os.path.exists(output_subdir):
                        os.makedirs(output_subdir)  # Membuat subfolder jika belum ada

                    output_path = os.path.join(output_subdir, output_filename)

                    # Konversi gambar dan simpan
                    image_jpeg = convert_image_to_jpeg(image_path, target_size)
                    save_converted_image(image_jpeg, output_path)
                    print(f"Berhasil mengonversi {image_path} ke {output_path}")
                else:
                    print(f"{image_path} tidak valid, tidak diproses.")

# 6. Menjalankan fungsi untuk folder 'train' dan 'validation'
convert_all_images_to_jpeg(train_images_dir, '/content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train')
convert_all_images_to_jpeg(val_images_dir, '/content/dataset/ML_ObjectDetectionModelSmall/data_augmented/val')
# Out:
# Streaming output truncated to the last 5000 lines.
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/kemiri/kemiri_72.JPG ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/kemiri/kemiri_72.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/kemiri/kemiri_178.JPG ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/kemiri/kemiri_178.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/kemiri/kemiri_146.JPG ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/kemiri/kemiri_146.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/kemiri/kemiri_164.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/kemiri/kemiri_164.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/kemiri/kemiri_29.JPG ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/kemiri/kemiri_29.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/kemiri/kemiri_82.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/kemiri/kemiri_82.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/kemiri/kemiri_183.JPG ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/kemiri/kemiri_183.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/kemiri/kemiri_12.JPG ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/kemiri/kemiri_12.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/kemiri/kemiri_159.JPG ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/kemiri/kemiri_159.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/kemiri/kemiri_158.JPG ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/kemiri/kemiri_158.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/kemiri/kemiri_165.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/kemiri/kemiri_165.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/kemiri/kemiri_15.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/kemiri/kemiri_15.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/kemiri/kemiri_38.JPG ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/kemiri/kemiri_38.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/kemiri/kemiri_144.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/kemiri/kemiri_144.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/kemiri/kemiri_24.JPG ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/kemiri/kemiri_24.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/kemiri/kemiri_31.JPG ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/kemiri/kemiri_31.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/kemiri/kemiri_91.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/kemiri/kemiri_91.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/kemiri/kemiri_56.JPG ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/kemiri/kemiri_56.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/kemiri/kemiri_166.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/kemiri/kemiri_166.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/kemiri/kemiri_202.JPG ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/kemiri/kemiri_202.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/kemiri/kemiri_68.JPG ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/kemiri/kemiri_68.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/kemiri/kemiri_161.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/kemiri/kemiri_161.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/kemiri/kemiri_20.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/kemiri/kemiri_20.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/kemiri/kemiri_95.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/kemiri/kemiri_95.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/kemiri/kemiri_101.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/kemiri/kemiri_101.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/kemiri/kemiri_30.JPG ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/kemiri/kemiri_30.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/kemiri/kemiri_189.JPG ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/kemiri/kemiri_189.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/kemiri/kemiri_181.JPG ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/kemiri/kemiri_181.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/kemiri/kemiri_63.JPG ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/kemiri/kemiri_63.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/kemiri/kemiri_121.JPG ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/kemiri/kemiri_121.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/kemiri/kemiri_184.JPG ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/kemiri/kemiri_184.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/kemiri/kemiri_21.JPG ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/kemiri/kemiri_21.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/kemiri/kemiri_106.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/kemiri/kemiri_106.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/kemiri/kemiri_109.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/kemiri/kemiri_109.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/kemiri/kemiri_26.JPG ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/kemiri/kemiri_26.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/kemiri/kemiri_105.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/kemiri/kemiri_105.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/kemiri/kemiri_10.JPG ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/kemiri/kemiri_10.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/kemiri/kemiri_162.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/kemiri/kemiri_162.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/kemiri/kemiri_39.JPG ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/kemiri/kemiri_39.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/kemiri/kemiri_127.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/kemiri/kemiri_127.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/kemiri/kemiri_35.JPG ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/kemiri/kemiri_35.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/kemiri/kemiri_112.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/kemiri/kemiri_112.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/kemiri/kemiri_62.JPG ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/kemiri/kemiri_62.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/kemiri/kemiri_74.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/kemiri/kemiri_74.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/kemiri/kemiri_41.JPG ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/kemiri/kemiri_41.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/kemiri/kemiri_180.JPG ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/kemiri/kemiri_180.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/kemiri/kemiri_123.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/kemiri/kemiri_123.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/kemiri/kemiri_27.JPG ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/kemiri/kemiri_27.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/kemiri/kemiri_203.JPG ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/kemiri/kemiri_203.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/kemiri/kemiri_169.JPG ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/kemiri/kemiri_169.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/kemiri/kemiri_198.JPG ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/kemiri/kemiri_198.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/kemiri/kemiri_67.JPG ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/kemiri/kemiri_67.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/kemiri/kemiri_9.JPG ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/kemiri/kemiri_9.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/kemiri/kemiri_54.JPG ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/kemiri/kemiri_54.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/kemiri/kemiri_182.JPG ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/kemiri/kemiri_182.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/kemiri/kemiri_149.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/kemiri/kemiri_149.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/kemiri/kemiri_192.JPG ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/kemiri/kemiri_192.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/kemiri/kemiri_70.JPG ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/kemiri/kemiri_70.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/cengkeh/cengkeh_135.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/cengkeh/cengkeh_135.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/cengkeh/cengkeh_154.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/cengkeh/cengkeh_154.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/cengkeh/cengkeh_192.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/cengkeh/cengkeh_192.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/cengkeh/cengkeh_103.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/cengkeh/cengkeh_103.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/cengkeh/cengkeh_175.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/cengkeh/cengkeh_175.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/cengkeh/cengkeh_109.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/cengkeh/cengkeh_109.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/cengkeh/cengkeh_133.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/cengkeh/cengkeh_133.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/cengkeh/cengkeh_34.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/cengkeh/cengkeh_34.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/cengkeh/cengkeh_184.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/cengkeh/cengkeh_184.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/cengkeh/cengkeh_126.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/cengkeh/cengkeh_126.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/cengkeh/cengkeh_152.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/cengkeh/cengkeh_152.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/cengkeh/cengkeh_117.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/cengkeh/cengkeh_117.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/cengkeh/cengkeh_199.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/cengkeh/cengkeh_199.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/cengkeh/cengkeh_173.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/cengkeh/cengkeh_173.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/cengkeh/cengkeh_201.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/cengkeh/cengkeh_201.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/cengkeh/cengkeh_12.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/cengkeh/cengkeh_12.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/cengkeh/cengkeh_18.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/cengkeh/cengkeh_18.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/cengkeh/cengkeh_51.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/cengkeh/cengkeh_51.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/cengkeh/cengkeh_158.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/cengkeh/cengkeh_158.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/cengkeh/cengkeh_37.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/cengkeh/cengkeh_37.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/cengkeh/cengkeh_15.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/cengkeh/cengkeh_15.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/cengkeh/cengkeh_202.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/cengkeh/cengkeh_202.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/cengkeh/cengkeh_143.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/cengkeh/cengkeh_143.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/cengkeh/cengkeh_112.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/cengkeh/cengkeh_112.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/cengkeh/cengkeh_77.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/cengkeh/cengkeh_77.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/cengkeh/cengkeh_139.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/cengkeh/cengkeh_139.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/cengkeh/cengkeh_56.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/cengkeh/cengkeh_56.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/cengkeh/cengkeh_200.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/cengkeh/cengkeh_200.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/cengkeh/cengkeh_29.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/cengkeh/cengkeh_29.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/cengkeh/cengkeh_198.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/cengkeh/cengkeh_198.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/cengkeh/cengkeh_115.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/cengkeh/cengkeh_115.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/cengkeh/cengkeh_23.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/cengkeh/cengkeh_23.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/cengkeh/cengkeh_21.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/cengkeh/cengkeh_21.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/cengkeh/cengkeh_189.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/cengkeh/cengkeh_189.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/cengkeh/cengkeh_121.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/cengkeh/cengkeh_121.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/cengkeh/cengkeh_54.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/cengkeh/cengkeh_54.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/cengkeh/cengkeh_114.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/cengkeh/cengkeh_114.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/cengkeh/cengkeh_127.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/cengkeh/cengkeh_127.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/cengkeh/cengkeh_209.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/cengkeh/cengkeh_209.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/cengkeh/cengkeh_35.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/cengkeh/cengkeh_35.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/cengkeh/cengkeh_196.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/cengkeh/cengkeh_196.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/cengkeh/cengkeh_118.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/cengkeh/cengkeh_118.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/cengkeh/cengkeh_71.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/cengkeh/cengkeh_71.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/cengkeh/cengkeh_128.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/cengkeh/cengkeh_128.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/cengkeh/cengkeh_147.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/cengkeh/cengkeh_147.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/cengkeh/cengkeh_80.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/cengkeh/cengkeh_80.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/cengkeh/cengkeh_45.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/cengkeh/cengkeh_45.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/cengkeh/cengkeh_14.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/cengkeh/cengkeh_14.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/cengkeh/cengkeh_164.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/cengkeh/cengkeh_164.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/cengkeh/cengkeh_195.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/cengkeh/cengkeh_195.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/cengkeh/cengkeh_178.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/cengkeh/cengkeh_178.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/cengkeh/cengkeh_105.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/cengkeh/cengkeh_105.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/cengkeh/cengkeh_89.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/cengkeh/cengkeh_89.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/cengkeh/cengkeh_87.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/cengkeh/cengkeh_87.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/cengkeh/cengkeh_182.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/cengkeh/cengkeh_182.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/cengkeh/cengkeh_136.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/cengkeh/cengkeh_136.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/cengkeh/cengkeh_107.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/cengkeh/cengkeh_107.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/cengkeh/cengkeh_155.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/cengkeh/cengkeh_155.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/cengkeh/cengkeh_79.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/cengkeh/cengkeh_79.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/cengkeh/cengkeh_92.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/cengkeh/cengkeh_92.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/cengkeh/cengkeh_148.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/cengkeh/cengkeh_148.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/cengkeh/cengkeh_163.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/cengkeh/cengkeh_163.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/cengkeh/cengkeh_169.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/cengkeh/cengkeh_169.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/cengkeh/cengkeh_90.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/cengkeh/cengkeh_90.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/cengkeh/cengkeh_50.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/cengkeh/cengkeh_50.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/cengkeh/cengkeh_204.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/cengkeh/cengkeh_204.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/cengkeh/cengkeh_168.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/cengkeh/cengkeh_168.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/cengkeh/cengkeh_24.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/cengkeh/cengkeh_24.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/cengkeh/cengkeh_26.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/cengkeh/cengkeh_26.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/cengkeh/cengkeh_179.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/cengkeh/cengkeh_179.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/cengkeh/cengkeh_125.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/cengkeh/cengkeh_125.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/cengkeh/cengkeh_32.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/cengkeh/cengkeh_32.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/cengkeh/cengkeh_123.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/cengkeh/cengkeh_123.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/cengkeh/cengkeh_33.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/cengkeh/cengkeh_33.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/cengkeh/cengkeh_140.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/cengkeh/cengkeh_140.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/cengkeh/cengkeh_124.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/cengkeh/cengkeh_124.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/cengkeh/cengkeh_146.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/cengkeh/cengkeh_146.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/cengkeh/cengkeh_36.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/cengkeh/cengkeh_36.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/cengkeh/cengkeh_78.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/cengkeh/cengkeh_78.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/cengkeh/cengkeh_76.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/cengkeh/cengkeh_76.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/cengkeh/cengkeh_160.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/cengkeh/cengkeh_160.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/cengkeh/cengkeh_207.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/cengkeh/cengkeh_207.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/cengkeh/cengkeh_70.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/cengkeh/cengkeh_70.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/cengkeh/cengkeh_42.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/cengkeh/cengkeh_42.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/cengkeh/cengkeh_65.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/cengkeh/cengkeh_65.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/cengkeh/cengkeh_104.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/cengkeh/cengkeh_104.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/cengkeh/cengkeh_49.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/cengkeh/cengkeh_49.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/cengkeh/cengkeh_170.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/cengkeh/cengkeh_170.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/cengkeh/cengkeh_25.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/cengkeh/cengkeh_25.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/cengkeh/cengkeh_102.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/cengkeh/cengkeh_102.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/cengkeh/cengkeh_73.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/cengkeh/cengkeh_73.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/cengkeh/cengkeh_120.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/cengkeh/cengkeh_120.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/cengkeh/cengkeh_205.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/cengkeh/cengkeh_205.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/cengkeh/cengkeh_172.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/cengkeh/cengkeh_172.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/cengkeh/cengkeh_98.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/cengkeh/cengkeh_98.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/cengkeh/cengkeh_181.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/cengkeh/cengkeh_181.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/cengkeh/cengkeh_22.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/cengkeh/cengkeh_22.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/cengkeh/cengkeh_206.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/cengkeh/cengkeh_206.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/cengkeh/cengkeh_101.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/cengkeh/cengkeh_101.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/cengkeh/cengkeh_72.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/cengkeh/cengkeh_72.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/cengkeh/cengkeh_157.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/cengkeh/cengkeh_157.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/cengkeh/cengkeh_166.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/cengkeh/cengkeh_166.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/cengkeh/cengkeh_156.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/cengkeh/cengkeh_156.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/cengkeh/cengkeh_41.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/cengkeh/cengkeh_41.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/cengkeh/cengkeh_96.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/cengkeh/cengkeh_96.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/cengkeh/cengkeh_88.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/cengkeh/cengkeh_88.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/cengkeh/cengkeh_151.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/cengkeh/cengkeh_151.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/cengkeh/cengkeh_142.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/cengkeh/cengkeh_142.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/cengkeh/cengkeh_85.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/cengkeh/cengkeh_85.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/cengkeh/cengkeh_91.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/cengkeh/cengkeh_91.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/cengkeh/cengkeh_180.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/cengkeh/cengkeh_180.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/cengkeh/cengkeh_162.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/cengkeh/cengkeh_162.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/cengkeh/cengkeh_86.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/cengkeh/cengkeh_86.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/cengkeh/cengkeh_149.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/cengkeh/cengkeh_149.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/cengkeh/cengkeh_31.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/cengkeh/cengkeh_31.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/cengkeh/cengkeh_16.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/cengkeh/cengkeh_16.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/cengkeh/cengkeh_141.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/cengkeh/cengkeh_141.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/cengkeh/cengkeh_69.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/cengkeh/cengkeh_69.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/cengkeh/cengkeh_177.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/cengkeh/cengkeh_177.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/cengkeh/cengkeh_176.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/cengkeh/cengkeh_176.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/cengkeh/cengkeh_28.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/cengkeh/cengkeh_28.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/cengkeh/cengkeh_57.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/cengkeh/cengkeh_57.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/cengkeh/cengkeh_60.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/cengkeh/cengkeh_60.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/cengkeh/cengkeh_58.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/cengkeh/cengkeh_58.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/cengkeh/cengkeh_9.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/cengkeh/cengkeh_9.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/cengkeh/cengkeh_17.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/cengkeh/cengkeh_17.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/cengkeh/cengkeh_110.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/cengkeh/cengkeh_110.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/cengkeh/cengkeh_171.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/cengkeh/cengkeh_171.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/cengkeh/cengkeh_27.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/cengkeh/cengkeh_27.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/cengkeh/cengkeh_75.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/cengkeh/cengkeh_75.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/cengkeh/cengkeh_113.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/cengkeh/cengkeh_113.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/cengkeh/cengkeh_188.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/cengkeh/cengkeh_188.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/cengkeh/cengkeh_159.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/cengkeh/cengkeh_159.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/cengkeh/cengkeh_95.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/cengkeh/cengkeh_95.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/cengkeh/cengkeh_64.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/cengkeh/cengkeh_64.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/cengkeh/cengkeh_67.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/cengkeh/cengkeh_67.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/cengkeh/cengkeh_130.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/cengkeh/cengkeh_130.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/cengkeh/cengkeh_55.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/cengkeh/cengkeh_55.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/cengkeh/cengkeh_167.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/cengkeh/cengkeh_167.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/cengkeh/cengkeh_66.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/cengkeh/cengkeh_66.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/cengkeh/cengkeh_111.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/cengkeh/cengkeh_111.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/cengkeh/cengkeh_43.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/cengkeh/cengkeh_43.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/cengkeh/cengkeh_99.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/cengkeh/cengkeh_99.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/cengkeh/cengkeh_161.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/cengkeh/cengkeh_161.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/cengkeh/cengkeh_190.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/cengkeh/cengkeh_190.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/cengkeh/cengkeh_10.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/cengkeh/cengkeh_10.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/cengkeh/cengkeh_82.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/cengkeh/cengkeh_82.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/cengkeh/cengkeh_144.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/cengkeh/cengkeh_144.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/cengkeh/cengkeh_40.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/cengkeh/cengkeh_40.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/cengkeh/cengkeh_108.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/cengkeh/cengkeh_108.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/cengkeh/cengkeh_47.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/cengkeh/cengkeh_47.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/cengkeh/cengkeh_194.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/cengkeh/cengkeh_194.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/cengkeh/cengkeh_132.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/cengkeh/cengkeh_132.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/cengkeh/cengkeh_48.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/cengkeh/cengkeh_48.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/cengkeh/cengkeh_208.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/cengkeh/cengkeh_208.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/cengkeh/cengkeh_63.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/cengkeh/cengkeh_63.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/cengkeh/cengkeh_94.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/cengkeh/cengkeh_94.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/cengkeh/cengkeh_19.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/cengkeh/cengkeh_19.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/cengkeh/cengkeh_174.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/cengkeh/cengkeh_174.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/cengkeh/cengkeh_11.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/cengkeh/cengkeh_11.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/cengkeh/cengkeh_61.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/cengkeh/cengkeh_61.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/cengkeh/cengkeh_39.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/cengkeh/cengkeh_39.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/cengkeh/cengkeh_59.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/cengkeh/cengkeh_59.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/cengkeh/cengkeh_116.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/cengkeh/cengkeh_116.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/cengkeh/cengkeh_30.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/cengkeh/cengkeh_30.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/cengkeh/cengkeh_84.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/cengkeh/cengkeh_84.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/cengkeh/cengkeh_129.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/cengkeh/cengkeh_129.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/cengkeh/cengkeh_20.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/cengkeh/cengkeh_20.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/cengkeh/cengkeh_68.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/cengkeh/cengkeh_68.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/cengkeh/cengkeh_203.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/cengkeh/cengkeh_203.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/cengkeh/cengkeh_183.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/cengkeh/cengkeh_183.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/cengkeh/cengkeh_165.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/cengkeh/cengkeh_165.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/cengkeh/cengkeh_153.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/cengkeh/cengkeh_153.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/cengkeh/cengkeh_44.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/cengkeh/cengkeh_44.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/cengkeh/cengkeh_185.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/cengkeh/cengkeh_185.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/cengkeh/cengkeh_119.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/cengkeh/cengkeh_119.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/cengkeh/cengkeh_137.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/cengkeh/cengkeh_137.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/cengkeh/cengkeh_46.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/cengkeh/cengkeh_46.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/cengkeh/cengkeh_145.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/cengkeh/cengkeh_145.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/cengkeh/cengkeh_83.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/cengkeh/cengkeh_83.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/cengkeh/cengkeh_210.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/cengkeh/cengkeh_210.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/cengkeh/cengkeh_197.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/cengkeh/cengkeh_197.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/cengkeh/cengkeh_52.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/cengkeh/cengkeh_52.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/cengkeh/cengkeh_193.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/cengkeh/cengkeh_193.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/cengkeh/cengkeh_74.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/cengkeh/cengkeh_74.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/cengkeh/cengkeh_131.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/cengkeh/cengkeh_131.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/cengkeh/cengkeh_13.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/cengkeh/cengkeh_13.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/cengkeh/cengkeh_38.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/cengkeh/cengkeh_38.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/train/cengkeh/cengkeh_81.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train/cengkeh/cengkeh_81.jpg
# ...
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/validation/wortel/Image_8.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/val/wortel/Image_8.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/validation/wortel/Image_3.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/val/wortel/Image_3.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/validation/wortel/Image_10.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/val/wortel/Image_10.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/validation/wortel/Image_1.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/val/wortel/Image_1.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/validation/wortel/Image_7.JPG ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/val/wortel/Image_7.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/validation/wortel/Image_4.png ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/val/wortel/Image_4.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/validation/wortel/Image_6.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/val/wortel/Image_6.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/validation/wortel/Image_2.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/val/wortel/Image_2.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/validation/lengkuas/lengkuas_4.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/val/lengkuas/lengkuas_4.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/validation/lengkuas/lengkuas_5.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/val/lengkuas/lengkuas_5.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/validation/lengkuas/lengkuas_7.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/val/lengkuas/lengkuas_7.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/validation/lengkuas/lengkuas_2.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/val/lengkuas/lengkuas_2.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/validation/lengkuas/lengkuas_3.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/val/lengkuas/lengkuas_3.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/validation/lengkuas/lengkuas_6.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/val/lengkuas/lengkuas_6.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/validation/lengkuas/lengkuas_1.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/val/lengkuas/lengkuas_1.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/validation/lengkuas/lengkuas_8.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/val/lengkuas/lengkuas_8.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/validation/tempe/1-s2-0-S1878450X21001128-gr1--1-_jpg.rf.d110c999e3e131c02b62d8054cc84a40.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/val/tempe/1-s2-0-S1878450X21001128-gr1--1-_jpg.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/validation/tempe/1c1580d9-3da7-4d9c-8c9f-1bdeccfd759e_jpg.rf.8657629cacde9c5685fa09a8995b47c9.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/val/tempe/1c1580d9-3da7-4d9c-8c9f-1bdeccfd759e_jpg.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/validation/tempe/-1_7980a16e-c7a2-47b4-8184-8f071fa0b078_jpg.rf.c1cc7bb639b1435bf876a3ba922b5381.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/val/tempe/-1_7980a16e-c7a2-47b4-8184-8f071fa0b078_jpg.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/validation/tempe/3b57eb4c-0c0c-4b8a-b24b-f1e7c4fd15a5_jpg.rf.0751eb9e2080bde082cc96108328a734.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/val/tempe/3b57eb4c-0c0c-4b8a-b24b-f1e7c4fd15a5_jpg.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/validation/tempe/0ef22a67366bb287a201ad04f9d9440a_jpg.rf.04e69e5cf4483b32d556b39e7deed417.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/val/tempe/0ef22a67366bb287a201ad04f9d9440a_jpg.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/validation/tempe/1fee48cf5f589f9e8727e314d48b4379_jpg.rf.dfe8682e255b84483dac47bb977f2ac5.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/val/tempe/1fee48cf5f589f9e8727e314d48b4379_jpg.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/validation/tempe/1c799193-415f-4d95-882f-7111a40ae26c_43_jpg.rf.e556627949e51f4a8732fc3e5bbc9cf8.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/val/tempe/1c799193-415f-4d95-882f-7111a40ae26c_43_jpg.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/validation/tempe/0_fdedebef-7d32-4e60-9399-68aa068355a1_640_480_jpg.rf.fc1c3e19f559e0e917b55ae47e19e229.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/val/tempe/0_fdedebef-7d32-4e60-9399-68aa068355a1_640_480_jpg.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/validation/bayam/Image_94.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/val/bayam/Image_94.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/validation/bayam/Image_95.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/val/bayam/Image_95.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/validation/bayam/Image_96.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/val/bayam/Image_96.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/validation/bayam/Image_98.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/val/bayam/Image_98.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/validation/bayam/Image_100.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/val/bayam/Image_100.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/validation/bayam/Image_99.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/val/bayam/Image_99.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/validation/bayam/Image_97.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/val/bayam/Image_97.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/validation/daunsalam/daun-salam_6.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/val/daunsalam/daun-salam_6.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/validation/daunsalam/daun-salam_1.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/val/daunsalam/daun-salam_1.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/validation/daunsalam/daun-salam_5.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/val/daunsalam/daun-salam_5.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/validation/daunsalam/daun-salam_3.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/val/daunsalam/daun-salam_3.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/validation/daunsalam/daun-salam_8.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/val/daunsalam/daun-salam_8.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/validation/daunsalam/daun-salam_2.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/val/daunsalam/daun-salam_2.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/validation/daunsalam/daun-salam_7.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/val/daunsalam/daun-salam_7.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/validation/daunsalam/daun-salam_4.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/val/daunsalam/daun-salam_4.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/validation/kol/Image_5.JPG ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/val/kol/Image_5.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/validation/kol/Image_7.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/val/kol/Image_7.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/validation/kol/Image_4.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/val/kol/Image_4.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/validation/kol/Image_8.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/val/kol/Image_8.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/validation/kol/Image_3.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/val/kol/Image_3.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/validation/kol/Image_1.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/val/kol/Image_1.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/validation/kol/Image_6.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/val/kol/Image_6.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/validation/kol/Image_2.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/val/kol/Image_2.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/validation/jahe/Image_7.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/val/jahe/Image_7.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/validation/jahe/Image_4.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/val/jahe/Image_4.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/validation/jahe/Image_5.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/val/jahe/Image_5.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/validation/jahe/Image_8.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/val/jahe/Image_8.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/validation/jahe/Image_3.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/val/jahe/Image_3.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/validation/jahe/Image_1.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/val/jahe/Image_1.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/validation/jahe/Image_6.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/val/jahe/Image_6.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/validation/jahe/Image_2.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/val/jahe/Image_2.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/validation/kubis/Image_7.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/val/kubis/Image_7.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/validation/kubis/Image_4.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/val/kubis/Image_4.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/validation/kubis/Image_5.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/val/kubis/Image_5.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/validation/kubis/Image_8.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/val/kubis/Image_8.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/validation/kubis/Image_3.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/val/kubis/Image_3.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/validation/kubis/Image_1.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/val/kubis/Image_1.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/validation/kubis/Image_6.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/val/kubis/Image_6.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/validation/kubis/Image_2.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/val/kubis/Image_2.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/validation/jinten/jinten_5.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/val/jinten/jinten_5.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/validation/jinten/jinten_3.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/val/jinten/jinten_3.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/validation/jinten/jinten_6.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/val/jinten/jinten_6.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/validation/jinten/jinten_2.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/val/jinten/jinten_2.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/validation/jinten/jinten_8.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/val/jinten/jinten_8.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/validation/jinten/jinten_4.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/val/jinten/jinten_4.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/validation/jinten/jinten_1.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/val/jinten/jinten_1.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/validation/jinten/jinten_7.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/val/jinten/jinten_7.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/validation/caberawit/Image_18.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/val/caberawit/Image_18.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/validation/caberawit/Image_20.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/val/caberawit/Image_20.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/validation/caberawit/Image_24.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/val/caberawit/Image_24.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/validation/caberawit/Image_21.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/val/caberawit/Image_21.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/validation/caberawit/Image_26.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/val/caberawit/Image_26.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/validation/caberawit/Image_22.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/val/caberawit/Image_22.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/validation/caberawit/Image_23.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/val/caberawit/Image_23.jpg
# Berhasil mengonversi /content/dataset/ML_ObjectDetectionModelSmall/data/validation/caberawit/Image_17.jpg ke /content/dataset/ML_ObjectDetectionModelSmall/data_augmented/val/caberawit/Image_17.jpg

# %%
augmented_train_dir = '/content/dataset/ML_ObjectDetectionModelSmall/data_augmented/train'
augmented_val_dir = '/content/dataset/ML_ObjectDetectionModelSmall/data_augmented/val'
Tf_record_dir = '/content/dataset/ML_ObjectDetectionModelSmall/tf_record'

# %%
def create_yolo_labels(image_path, class_id, image_size=(416, 416)):
    """
    Membuat anotasi YOLO berdasarkan ukuran gambar penuh (bounding box penuh).
    """
    # Membaca gambar dan mengubah ukurannya
    image = tf.io.read_file(image_path)
    image = tf.image.decode_jpeg(image, channels=3)
    image = tf.image.resize(image, image_size) / 255.0  # Normalisasi ke [0, 1]

    # Tentukan bounding box penuh
    h, w, _ = image.shape
    x_center = 0.5
    y_center = 0.5
    width = 1.0
    height = 1.0

    # Format YOLO: [class_id, x_center, y_center, width, height]
    label = np.array([class_id, x_center, y_center, width, height], dtype=np.float32)

    return image, label

# %%
def image_to_tfrecord(image_path, label, image_size=(416, 416)):
    image = tf.io.read_file(image_path)
    image = tf.image.decode_jpeg(image, channels=3)
    image = tf.image.resize(image, image_size)  # Resize gambar
    image = tf.io.encode_jpeg(image)  # Encode gambar menjadi JPEG

    feature = {
        'image': tf.train.Feature(bytes_list=tf.train.BytesList(value=[image.numpy()])),  # Gambar
        'label': tf.train.Feature(int64_list=tf.train.Int64List(value=[label]))  # Label
    }

    example = tf.train.Example(features=tf.train.Features(feature=feature))
    return example

# %%
def augment_data(image, label):
    # Contoh augmentasi
    image = tf.image.random_flip_left_right(image)  # Flip horizontal
    image = tf.image.random_flip_up_down(image)  # Flip vertikal
    image = tf.image.random_contrast(image, lower=0.2, upper=1.8)  # Kontras acak
    image = tf.image.random_brightness(image, max_delta=0.2)  # Kecerahan acak

    # Anda bisa menambahkan augmentasi lainnya seperti rotasi, zoom, dll.

    return image, label

# %%
def write_tfrecord(image_paths, labels, output_path):
    # Menulis file TFRecord
    with tf.io.TFRecordWriter(output_path) as writer:
        for img_path, label in zip(image_paths, labels):
            # Membaca gambar
            image = tf.io.read_file(img_path)
            image = tf.image.decode_jpeg(image, channels=3)  # Decode gambar JPG

            # Normalisasi gambar ke [0, 255] dan ubah tipe data menjadi uint8
            image = tf.image.convert_image_dtype(image, dtype=tf.uint8)

            # Membuat fitur untuk gambar dan label
            feature = {
                'image': tf.train.Feature(bytes_list=tf.train.BytesList(value=[tf.io.encode_jpeg(image).numpy()])),
                'label': tf.train.Feature(int64_list=tf.train.Int64List(value=[label]))
            }

            # Membuat contoh (Example) dan menulisnya ke TFRecord
            example = tf.train.Example(features=tf.train.Features(feature=feature))
            writer.write(example.SerializeToString())

# %%
def is_image_file(file_path):
    try:
        # Membaca gambar untuk memastikan file tersebut valid
        image = tf.io.read_file(file_path)
        image = tf.image.decode_jpeg(image, channels=3)  # Coba decode sebagai JPEG
        return True  # Jika berhasil, file adalah gambar yang valid
    except tf.errors.InvalidArgumentError:
        return False  # Jika gagal decode, file bukan gambar atau format rusak

# %%
def prepare_and_convert_to_tfrecord(image_dir, output_dir, image_size=(416, 416)):
    class_names = sorted(os.listdir(image_dir))  # Daftar nama subfolder yang jadi kelas
    image_paths = []
    labels = []

    for class_id, class_name in enumerate(class_names):
        class_folder = os.path.join(image_dir, class_name)
        if os.path.isdir(class_folder):
            for img_name in os.listdir(class_folder):
                img_path = os.path.join(class_folder, img_name)
                if is_image_file(img_path):  # Hanya tambahkan file gambar yang valid
                    image_paths.append(img_path)
                    labels.append(class_id)  # Label sesuai dengan urutan subfolder

    # Tentukan file output TFRecord
    output_path = os.path.join(output_dir, 'dataset.tfrecord')
    write_tfrecord(image_paths, labels, output_path)

    # Kembalikan paths, labels, dan class_names
    return image_paths, labels, class_names

# %%
def _parse_function(proto):
    keys_to_features = {
        'image': tf.io.FixedLenFeature([], tf.string),  # Gambar dalam format string
        'label': tf.io.FixedLenFeature([1], tf.int64),  # Label sebagai integer
    }

    parsed_features = tf.io.parse_single_example(proto, keys_to_features)

    # Decode gambar
    image = tf.io.decode_jpeg(parsed_features['image'])
    label = parsed_features['label'][0]

    # Resizing gambar ke ukuran yang diinginkan
    image = tf.image.resize(image, [416, 416])  # Sesuaikan dengan ukuran input model Anda

    return image, label

# %%
def load_tfrecord_dataset(tfrecord_file, batch_size=16, augment=False):
    # Memuat dataset dari file TFRecord
    dataset = tf.data.TFRecordDataset([tfrecord_file])

    # Parsing data
    dataset = dataset.map(_parse_function)

    if augment:
        # Terapkan augmentasi jika diperlukan
        dataset = dataset.map(augment_data)

    # Shuffle, batching, dan prefetch untuk performa yang lebih baik
    dataset = dataset.shuffle(buffer_size=1000)
    dataset = dataset.batch(batch_size)
    dataset = dataset.prefetch(tf.data.experimental.AUTOTUNE)  # Prefetch untuk mempercepat pemrosesan
    return dataset

# %%
#hapus dlu folder anotasi(disemua subfolder)

# %%
train_image_paths, train_labels, train_class_names = prepare_and_convert_to_tfrecord(train_images_dir, Tf_record_dir)
val_image_paths, val_labels, val_class_names = prepare_and_convert_to_tfrecord(val_images_dir, Tf_record_dir)

# %%
# 7. Memuat dataset dari file TFRecord untuk train dan validation
train_tfrecord_file = os.path.join(Tf_record_dir, 'train.tfrecord')
val_tfrecord_file = os.path.join(Tf_record_dir, 'validation.tfrecord')

train_dataset = load_tfrecord_dataset(train_tfrecord_file, batch_size=16, augment=True)  # Terapkan augmentasi pada data training
val_dataset = load_tfrecord_dataset(val_tfrecord_file, batch_size=16, augment=False)  # Tidak perlu augmentasi pada data validation

# %%
backbone = keras_cv.models.YOLOV8Backbone.from_preset(
    "yolo_v8_s_backbone_coco"  # We will use yolov8 small backbone with coco weights
)

# %%
model = keras_cv.models.YOLOV8Detector(
    bounding_box_format="xywh",  # Format YOLO
    num_classes=len(train_class_names),  # Jumlah kelas yang ditemukan
    backbone=backbone,  # Gunakan backbone default dari YOLOv8
)

# %%
# Cek output model
print(model.output)
# Out:
# {'boxes': <KerasTensor shape=(None, None, 64), dtype=float32, sparse=False, name=keras_tensor_1038>, 'classes': <KerasTensor shape=(None, None, 30), dtype=float32, sparse=False, name=keras_tensor_1039>}

# %%
import tensorflow as tf
from tensorflow.keras import layers, models

# Custom layer to expand dimensions
class ExpandDimsLayer(layers.Layer):
    def __init__(self, axis=1):
        super(ExpandDimsLayer, self).__init__()
        self.axis = axis

    def call(self, inputs):
        return tf.expand_dims(inputs, axis=self.axis)

# Ambil output kelas dari model
classes_output = model.output['classes']

# Terapkan custom layer untuk menambahkan dimensi
x = ExpandDimsLayer(axis=1)(classes_output)  # Menambahkan dimensi height (None, 1, None, 3)

# Terapkan GlobalAveragePooling2D ke output kelas
x = tf.keras.layers.GlobalAveragePooling2D()(x)

# Menambahkan dense layer
x = tf.keras.layers.Dense(512, activation="relu")(x)  # Dense layer pertama
x = tf.keras.layers.Dense(256, activation="relu")(x)  # Dense layer kedua

# Output layer
output = tf.keras.layers.Dense(len(train_class_names), activation="softmax")(x)

# Membuat model baru dengan input dari model lama dan output dari layer Dense yang ditambahkan
custom_model = tf.keras.Model(inputs=model.input, outputs=output)

# Kompilasi model
custom_model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# Summary dari model untuk memeriksa arsitektur
custom_model.summary()
# Out:
# Model: "functional_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_5             │ (None, None, None, 3)  │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ functional_2 (Functional) │ [(None, None, None,    │      5,089,760 │ input_layer_5[0][0]    │
# │                           │ 128), (None, None,     │                │                        │
# │                           │ None, 256), (None,     │                │                        │
# │                           │ None, None, 512)]      │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ repeat_4 (Repeat)         │ (None, None, None,     │              0 │ functional_2[0][2]     │
# │                           │ 512)                   │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ repeat_5 (Repeat)         │ (None, None, None,     │              0 │ repeat_4[0][0]         │
# │                           │ 512)                   │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_22            │ (None, None, None,     │              0 │ repeat_5[0][0],        │
# │ (Concatenate)             │ 768)                   │                │ functional_2[0][1]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ pa_fpn_p4p5_pre_conv      │ (None, None, None,     │        196,608 │ concatenate_22[0][0]   │
# │ (Conv2D)                  │ 256)                   │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ pa_fpn_p4p5_pre_bn        │ (None, None, None,     │          1,024 │ pa_fpn_p4p5_pre_conv[… │
# │ (BatchNormalization)      │ 256)                   │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ pa_fpn_p4p5_pre           │ (None, None, None,     │              0 │ pa_fpn_p4p5_pre_bn[0]… │
# │ (Activation)              │ 256)                   │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ split_12 (Split)          │ [(None, None, None,    │              0 │ pa_fpn_p4p5_pre[0][0]  │
# │                           │ 128), (None, None,     │                │                        │
# │                           │ None, 128)]            │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ pa_fpn_p4p5_pre_0_1_pad   │ (None, None, None,     │              0 │ split_12[0][1]         │
# │ (ZeroPadding2D)           │ 128)                   │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ pa_fpn_p4p5_pre_0_1_conv  │ (None, None, None,     │        147,456 │ pa_fpn_p4p5_pre_0_1_p… │
# │ (Conv2D)                  │ 128)                   │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ pa_fpn_p4p5_pre_0_1_bn    │ (None, None, None,     │            512 │ pa_fpn_p4p5_pre_0_1_c… │
# │ (BatchNormalization)      │ 128)                   │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ pa_fpn_p4p5_pre_0_1       │ (None, None, None,     │              0 │ pa_fpn_p4p5_pre_0_1_b… │
# │ (Activation)              │ 128)                   │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ pa_fpn_p4p5_pre_0_2_pad   │ (None, None, None,     │              0 │ pa_fpn_p4p5_pre_0_1[0… │
# │ (ZeroPadding2D)           │ 128)                   │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ pa_fpn_p4p5_pre_0_2_conv  │ (None, None, None,     │        147,456 │ pa_fpn_p4p5_pre_0_2_p… │
# │ (Conv2D)                  │ 128)                   │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ pa_fpn_p4p5_pre_0_2_bn    │ (None, None, None,     │            512 │ pa_fpn_p4p5_pre_0_2_c… │
# │ (BatchNormalization)      │ 128)                   │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ pa_fpn_p4p5_pre_0_2       │ (None, None, None,     │              0 │ pa_fpn_p4p5_pre_0_2_b… │
# │ (Activation)              │ 128)                   │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ pa_fpn_p4p5_pre_1_1_pad   │ (None, None, None,     │              0 │ pa_fpn_p4p5_pre_0_2[0… │
# │ (ZeroPadding2D)           │ 128)                   │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ pa_fpn_p4p5_pre_1_1_conv  │ (None, None, None,     │        147,456 │ pa_fpn_p4p5_pre_1_1_p… │
# │ (Conv2D)                  │ 128)                   │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ pa_fpn_p4p5_pre_1_1_bn    │ (None, None, None,     │            512 │ pa_fpn_p4p5_pre_1_1_c… │
# │ (BatchNormalization)      │ 128)                   │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ pa_fpn_p4p5_pre_1_1       │ (None, None, None,     │              0 │ pa_fpn_p4p5_pre_1_1_b… │
# │ (Activation)              │ 128)                   │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ pa_fpn_p4p5_pre_1_2_pad   │ (None, None, None,     │              0 │ pa_fpn_p4p5_pre_1_1[0… │
# │ (ZeroPadding2D)           │ 128)                   │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ pa_fpn_p4p5_pre_1_2_conv  │ (None, None, None,     │        147,456 │ pa_fpn_p4p5_pre_1_2_p… │
# │ (Conv2D)                  │ 128)                   │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ pa_fpn_p4p5_pre_1_2_bn    │ (None, None, None,     │            512 │ pa_fpn_p4p5_pre_1_2_c… │
# │ (BatchNormalization)      │ 128)                   │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ pa_fpn_p4p5_pre_1_2       │ (None, None, None,     │              0 │ pa_fpn_p4p5_pre_1_2_b… │
# │ (Activation)              │ 128)                   │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_23            │ (None, None, None,     │              0 │ split_12[0][0],        │
# │ (Concatenate)             │ 512)                   │                │ split_12[0][1],        │
# │                           │                        │                │ pa_fpn_p4p5_pre_0_2[0… │
# │                           │                        │                │ pa_fpn_p4p5_pre_1_2[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ pa_fpn_p4p5_output_conv   │ (None, None, None,     │        131,072 │ concatenate_23[0][0]   │
# │ (Conv2D)                  │ 256)                   │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ pa_fpn_p4p5_output_bn     │ (None, None, None,     │          1,024 │ pa_fpn_p4p5_output_co… │
# │ (BatchNormalization)      │ 256)                   │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ pa_fpn_p4p5_output        │ (None, None, None,     │              0 │ pa_fpn_p4p5_output_bn… │
# │ (Activation)              │ 256)                   │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ repeat_6 (Repeat)         │ (None, None, None,     │              0 │ pa_fpn_p4p5_output[0]… │
# │                           │ 256)                   │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ repeat_7 (Repeat)         │ (None, None, None,     │              0 │ repeat_6[0][0]         │
# │                           │ 256)                   │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_24            │ (None, None, None,     │              0 │ repeat_7[0][0],        │
# │ (Concatenate)             │ 384)                   │                │ functional_2[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ pa_fpn_p3p4p5_pre_conv    │ (None, None, None,     │         49,152 │ concatenate_24[0][0]   │
# │ (Conv2D)                  │ 128)                   │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ pa_fpn_p3p4p5_pre_bn      │ (None, None, None,     │            512 │ pa_fpn_p3p4p5_pre_con… │
# │ (BatchNormalization)      │ 128)                   │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ pa_fpn_p3p4p5_pre         │ (None, None, None,     │              0 │ pa_fpn_p3p4p5_pre_bn[… │
# │ (Activation)              │ 128)                   │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ split_13 (Split)          │ [(None, None, None,    │              0 │ pa_fpn_p3p4p5_pre[0][… │
# │                           │ 64), (None, None,      │                │                        │
# │                           │ None, 64)]             │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ pa_fpn_p3p4p5_pre_0_1_pad │ (None, None, None, 64) │              0 │ split_13[0][1]         │
# │ (ZeroPadding2D)           │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ pa_fpn_p3p4p5_pre_0_1_co… │ (None, None, None, 64) │         36,864 │ pa_fpn_p3p4p5_pre_0_1… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ pa_fpn_p3p4p5_pre_0_1_bn  │ (None, None, None, 64) │            256 │ pa_fpn_p3p4p5_pre_0_1… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ pa_fpn_p3p4p5_pre_0_1     │ (None, None, None, 64) │              0 │ pa_fpn_p3p4p5_pre_0_1… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ pa_fpn_p3p4p5_pre_0_2_pad │ (None, None, None, 64) │              0 │ pa_fpn_p3p4p5_pre_0_1… │
# │ (ZeroPadding2D)           │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ pa_fpn_p3p4p5_pre_0_2_co… │ (None, None, None, 64) │         36,864 │ pa_fpn_p3p4p5_pre_0_2… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ pa_fpn_p3p4p5_pre_0_2_bn  │ (None, None, None, 64) │            256 │ pa_fpn_p3p4p5_pre_0_2… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ pa_fpn_p3p4p5_pre_0_2     │ (None, None, None, 64) │              0 │ pa_fpn_p3p4p5_pre_0_2… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ pa_fpn_p3p4p5_pre_1_1_pad │ (None, None, None, 64) │              0 │ pa_fpn_p3p4p5_pre_0_2… │
# │ (ZeroPadding2D)           │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ pa_fpn_p3p4p5_pre_1_1_co… │ (None, None, None, 64) │         36,864 │ pa_fpn_p3p4p5_pre_1_1… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ pa_fpn_p3p4p5_pre_1_1_bn  │ (None, None, None, 64) │            256 │ pa_fpn_p3p4p5_pre_1_1… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ pa_fpn_p3p4p5_pre_1_1     │ (None, None, None, 64) │              0 │ pa_fpn_p3p4p5_pre_1_1… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ pa_fpn_p3p4p5_pre_1_2_pad │ (None, None, None, 64) │              0 │ pa_fpn_p3p4p5_pre_1_1… │
# │ (ZeroPadding2D)           │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ pa_fpn_p3p4p5_pre_1_2_co… │ (None, None, None, 64) │         36,864 │ pa_fpn_p3p4p5_pre_1_2… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ pa_fpn_p3p4p5_pre_1_2_bn  │ (None, None, None, 64) │            256 │ pa_fpn_p3p4p5_pre_1_2… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ pa_fpn_p3p4p5_pre_1_2     │ (None, None, None, 64) │              0 │ pa_fpn_p3p4p5_pre_1_2… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_25            │ (None, None, None,     │              0 │ split_13[0][0],        │
# │ (Concatenate)             │ 256)                   │                │ split_13[0][1],        │
# │                           │                        │                │ pa_fpn_p3p4p5_pre_0_2… │
# │                           │                        │                │ pa_fpn_p3p4p5_pre_1_2… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ pa_fpn_p3p4p5_output_conv │ (None, None, None,     │         32,768 │ concatenate_25[0][0]   │
# │ (Conv2D)                  │ 128)                   │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ pa_fpn_p3p4p5_output_bn   │ (None, None, None,     │            512 │ pa_fpn_p3p4p5_output_… │
# │ (BatchNormalization)      │ 128)                   │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ pa_fpn_p3p4p5_output      │ (None, None, None,     │              0 │ pa_fpn_p3p4p5_output_… │
# │ (Activation)              │ 128)                   │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ pa_fpn_p3p4p5_downsample… │ (None, None, None,     │              0 │ pa_fpn_p3p4p5_output[… │
# │ (ZeroPadding2D)           │ 128)                   │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ pa_fpn_p3p4p5_downsample… │ (None, None, None,     │        147,456 │ pa_fpn_p3p4p5_downsam… │
# │ (Conv2D)                  │ 128)                   │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ pa_fpn_p3p4p5_downsample… │ (None, None, None,     │            512 │ pa_fpn_p3p4p5_downsam… │
# │ (BatchNormalization)      │ 128)                   │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ pa_fpn_p3p4p5_downsample1 │ (None, None, None,     │              0 │ pa_fpn_p3p4p5_downsam… │
# │ (Activation)              │ 128)                   │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_26            │ (None, None, None,     │              0 │ pa_fpn_p3p4p5_downsam… │
# │ (Concatenate)             │ 384)                   │                │ pa_fpn_p4p5_output[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ pa_fpn_p3p4p5_downsample… │ (None, None, None,     │         98,304 │ concatenate_26[0][0]   │
# │ (Conv2D)                  │ 256)                   │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ pa_fpn_p3p4p5_downsample… │ (None, None, None,     │          1,024 │ pa_fpn_p3p4p5_downsam… │
# │ (BatchNormalization)      │ 256)                   │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ pa_fpn_p3p4p5_downsample… │ (None, None, None,     │              0 │ pa_fpn_p3p4p5_downsam… │
# │ (Activation)              │ 256)                   │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ split_14 (Split)          │ [(None, None, None,    │              0 │ pa_fpn_p3p4p5_downsam… │
# │                           │ 128), (None, None,     │                │                        │
# │                           │ None, 128)]            │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ pa_fpn_p3p4p5_downsample… │ (None, None, None,     │              0 │ split_14[0][1]         │
# │ (ZeroPadding2D)           │ 128)                   │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ pa_fpn_p3p4p5_downsample… │ (None, None, None,     │        147,456 │ pa_fpn_p3p4p5_downsam… │
# │ (Conv2D)                  │ 128)                   │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ pa_fpn_p3p4p5_downsample… │ (None, None, None,     │            512 │ pa_fpn_p3p4p5_downsam… │
# │ (BatchNormalization)      │ 128)                   │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ pa_fpn_p3p4p5_downsample… │ (None, None, None,     │              0 │ pa_fpn_p3p4p5_downsam… │
# │ (Activation)              │ 128)                   │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ pa_fpn_p3p4p5_downsample… │ (None, None, None,     │              0 │ pa_fpn_p3p4p5_downsam… │
# │ (ZeroPadding2D)           │ 128)                   │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ pa_fpn_p3p4p5_downsample… │ (None, None, None,     │        147,456 │ pa_fpn_p3p4p5_downsam… │
# │ (Conv2D)                  │ 128)                   │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ pa_fpn_p3p4p5_downsample… │ (None, None, None,     │            512 │ pa_fpn_p3p4p5_downsam… │
# │ (BatchNormalization)      │ 128)                   │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ pa_fpn_p3p4p5_downsample… │ (None, None, None,     │              0 │ pa_fpn_p3p4p5_downsam… │
# │ (Activation)              │ 128)                   │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ pa_fpn_p3p4p5_downsample… │ (None, None, None,     │              0 │ pa_fpn_p3p4p5_downsam… │
# │ (ZeroPadding2D)           │ 128)                   │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ pa_fpn_p3p4p5_downsample… │ (None, None, None,     │        147,456 │ pa_fpn_p3p4p5_downsam… │
# │ (Conv2D)                  │ 128)                   │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ pa_fpn_p3p4p5_downsample… │ (None, None, None,     │            512 │ pa_fpn_p3p4p5_downsam… │
# │ (BatchNormalization)      │ 128)                   │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ pa_fpn_p3p4p5_downsample… │ (None, None, None,     │              0 │ pa_fpn_p3p4p5_downsam… │
# │ (Activation)              │ 128)                   │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ pa_fpn_p3p4p5_downsample… │ (None, None, None,     │              0 │ pa_fpn_p3p4p5_downsam… │
# │ (ZeroPadding2D)           │ 128)                   │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ pa_fpn_p3p4p5_downsample… │ (None, None, None,     │        147,456 │ pa_fpn_p3p4p5_downsam… │
# │ (Conv2D)                  │ 128)                   │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ pa_fpn_p3p4p5_downsample… │ (None, None, None,     │            512 │ pa_fpn_p3p4p5_downsam… │
# │ (BatchNormalization)      │ 128)                   │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ pa_fpn_p3p4p5_downsample… │ (None, None, None,     │              0 │ pa_fpn_p3p4p5_downsam… │
# │ (Activation)              │ 128)                   │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_27            │ (None, None, None,     │              0 │ split_14[0][0],        │
# │ (Concatenate)             │ 512)                   │                │ split_14[0][1],        │
# │                           │                        │                │ pa_fpn_p3p4p5_downsam… │
# │                           │                        │                │ pa_fpn_p3p4p5_downsam… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ pa_fpn_p3p4p5_downsample… │ (None, None, None,     │        131,072 │ concatenate_27[0][0]   │
# │ (Conv2D)                  │ 256)                   │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ pa_fpn_p3p4p5_downsample… │ (None, None, None,     │          1,024 │ pa_fpn_p3p4p5_downsam… │
# │ (BatchNormalization)      │ 256)                   │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ pa_fpn_p3p4p5_downsample… │ (None, None, None,     │              0 │ pa_fpn_p3p4p5_downsam… │
# │ (Activation)              │ 256)                   │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ pa_fpn_p3p4p5_downsample… │ (None, None, None,     │              0 │ pa_fpn_p3p4p5_downsam… │
# │ (ZeroPadding2D)           │ 256)                   │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ pa_fpn_p3p4p5_downsample… │ (None, None, None,     │        589,824 │ pa_fpn_p3p4p5_downsam… │
# │ (Conv2D)                  │ 256)                   │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ pa_fpn_p3p4p5_downsample… │ (None, None, None,     │          1,024 │ pa_fpn_p3p4p5_downsam… │
# │ (BatchNormalization)      │ 256)                   │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ pa_fpn_p3p4p5_downsample2 │ (None, None, None,     │              0 │ pa_fpn_p3p4p5_downsam… │
# │ (Activation)              │ 256)                   │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_28            │ (None, None, None,     │              0 │ pa_fpn_p3p4p5_downsam… │
# │ (Concatenate)             │ 768)                   │                │ functional_2[0][2]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ pa_fpn_p3p4p5_downsample… │ (None, None, None,     │        393,216 │ concatenate_28[0][0]   │
# │ (Conv2D)                  │ 512)                   │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ pa_fpn_p3p4p5_downsample… │ (None, None, None,     │          2,048 │ pa_fpn_p3p4p5_downsam… │
# │ (BatchNormalization)      │ 512)                   │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ pa_fpn_p3p4p5_downsample… │ (None, None, None,     │              0 │ pa_fpn_p3p4p5_downsam… │
# │ (Activation)              │ 512)                   │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ split_15 (Split)          │ [(None, None, None,    │              0 │ pa_fpn_p3p4p5_downsam… │
# │                           │ 256), (None, None,     │                │                        │
# │                           │ None, 256)]            │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ pa_fpn_p3p4p5_downsample… │ (None, None, None,     │              0 │ split_15[0][1]         │
# │ (ZeroPadding2D)           │ 256)                   │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ pa_fpn_p3p4p5_downsample… │ (None, None, None,     │        589,824 │ pa_fpn_p3p4p5_downsam… │
# │ (Conv2D)                  │ 256)                   │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ pa_fpn_p3p4p5_downsample… │ (None, None, None,     │          1,024 │ pa_fpn_p3p4p5_downsam… │
# │ (BatchNormalization)      │ 256)                   │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ pa_fpn_p3p4p5_downsample… │ (None, None, None,     │              0 │ pa_fpn_p3p4p5_downsam… │
# │ (Activation)              │ 256)                   │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ pa_fpn_p3p4p5_downsample… │ (None, None, None,     │              0 │ pa_fpn_p3p4p5_downsam… │
# │ (ZeroPadding2D)           │ 256)                   │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ pa_fpn_p3p4p5_downsample… │ (None, None, None,     │        589,824 │ pa_fpn_p3p4p5_downsam… │
# │ (Conv2D)                  │ 256)                   │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ pa_fpn_p3p4p5_downsample… │ (None, None, None,     │          1,024 │ pa_fpn_p3p4p5_downsam… │
# │ (BatchNormalization)      │ 256)                   │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ pa_fpn_p3p4p5_downsample… │ (None, None, None,     │              0 │ pa_fpn_p3p4p5_downsam… │
# │ (Activation)              │ 256)                   │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ pa_fpn_p3p4p5_downsample… │ (None, None, None,     │              0 │ pa_fpn_p3p4p5_downsam… │
# │ (ZeroPadding2D)           │ 256)                   │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ pa_fpn_p3p4p5_downsample… │ (None, None, None,     │        589,824 │ pa_fpn_p3p4p5_downsam… │
# │ (Conv2D)                  │ 256)                   │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ pa_fpn_p3p4p5_downsample… │ (None, None, None,     │          1,024 │ pa_fpn_p3p4p5_downsam… │
# │ (BatchNormalization)      │ 256)                   │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ pa_fpn_p3p4p5_downsample… │ (None, None, None,     │              0 │ pa_fpn_p3p4p5_downsam… │
# │ (Activation)              │ 256)                   │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ pa_fpn_p3p4p5_downsample… │ (None, None, None,     │              0 │ pa_fpn_p3p4p5_downsam… │
# │ (ZeroPadding2D)           │ 256)                   │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ pa_fpn_p3p4p5_downsample… │ (None, None, None,     │        589,824 │ pa_fpn_p3p4p5_downsam… │
# │ (Conv2D)                  │ 256)                   │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ pa_fpn_p3p4p5_downsample… │ (None, None, None,     │          1,024 │ pa_fpn_p3p4p5_downsam… │
# │ (BatchNormalization)      │ 256)                   │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ pa_fpn_p3p4p5_downsample… │ (None, None, None,     │              0 │ pa_fpn_p3p4p5_downsam… │
# │ (Activation)              │ 256)                   │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_29            │ (None, None, None,     │              0 │ split_15[0][0],        │
# │ (Concatenate)             │ 1024)                  │                │ split_15[0][1],        │
# │                           │                        │                │ pa_fpn_p3p4p5_downsam… │
# │                           │                        │                │ pa_fpn_p3p4p5_downsam… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ pa_fpn_p3p4p5_downsample… │ (None, None, None,     │        524,288 │ concatenate_29[0][0]   │
# │ (Conv2D)                  │ 512)                   │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ pa_fpn_p3p4p5_downsample… │ (None, None, None,     │          2,048 │ pa_fpn_p3p4p5_downsam… │
# │ (BatchNormalization)      │ 512)                   │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ pa_fpn_p3p4p5_downsample… │ (None, None, None,     │              0 │ pa_fpn_p3p4p5_downsam… │
# │ (Activation)              │ 512)                   │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ yolo_v8_head_1_class_1_p… │ (None, None, None,     │              0 │ pa_fpn_p3p4p5_output[… │
# │ (ZeroPadding2D)           │ 128)                   │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ yolo_v8_head_2_class_1_p… │ (None, None, None,     │              0 │ pa_fpn_p3p4p5_downsam… │
# │ (ZeroPadding2D)           │ 256)                   │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ yolo_v8_head_3_class_1_p… │ (None, None, None,     │              0 │ pa_fpn_p3p4p5_downsam… │
# │ (ZeroPadding2D)           │ 512)                   │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ yolo_v8_head_1_box_1_pad  │ (None, None, None,     │              0 │ pa_fpn_p3p4p5_output[… │
# │ (ZeroPadding2D)           │ 128)                   │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ yolo_v8_head_1_class_1_c… │ (None, None, None,     │        147,456 │ yolo_v8_head_1_class_… │
# │ (Conv2D)                  │ 128)                   │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ yolo_v8_head_2_box_1_pad  │ (None, None, None,     │              0 │ pa_fpn_p3p4p5_downsam… │
# │ (ZeroPadding2D)           │ 256)                   │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ yolo_v8_head_2_class_1_c… │ (None, None, None,     │        294,912 │ yolo_v8_head_2_class_… │
# │ (Conv2D)                  │ 128)                   │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ yolo_v8_head_3_box_1_pad  │ (None, None, None,     │              0 │ pa_fpn_p3p4p5_downsam… │
# │ (ZeroPadding2D)           │ 512)                   │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ yolo_v8_head_3_class_1_c… │ (None, None, None,     │        589,824 │ yolo_v8_head_3_class_… │
# │ (Conv2D)                  │ 128)                   │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ yolo_v8_head_1_box_1_conv │ (None, None, None, 64) │         73,728 │ yolo_v8_head_1_box_1_… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ yolo_v8_head_1_class_1_bn │ (None, None, None,     │            512 │ yolo_v8_head_1_class_… │
# │ (BatchNormalization)      │ 128)                   │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ yolo_v8_head_2_box_1_conv │ (None, None, None, 64) │        147,456 │ yolo_v8_head_2_box_1_… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ yolo_v8_head_2_class_1_bn │ (None, None, None,     │            512 │ yolo_v8_head_2_class_… │
# │ (BatchNormalization)      │ 128)                   │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ yolo_v8_head_3_box_1_conv │ (None, None, None, 64) │        294,912 │ yolo_v8_head_3_box_1_… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ yolo_v8_head_3_class_1_bn │ (None, None, None,     │            512 │ yolo_v8_head_3_class_… │
# │ (BatchNormalization)      │ 128)                   │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ yolo_v8_head_1_box_1_bn   │ (None, None, None, 64) │            256 │ yolo_v8_head_1_box_1_… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ yolo_v8_head_1_class_1    │ (None, None, None,     │              0 │ yolo_v8_head_1_class_… │
# │ (Activation)              │ 128)                   │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ yolo_v8_head_2_box_1_bn   │ (None, None, None, 64) │            256 │ yolo_v8_head_2_box_1_… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ yolo_v8_head_2_class_1    │ (None, None, None,     │              0 │ yolo_v8_head_2_class_… │
# │ (Activation)              │ 128)                   │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ yolo_v8_head_3_box_1_bn   │ (None, None, None, 64) │            256 │ yolo_v8_head_3_box_1_… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ yolo_v8_head_3_class_1    │ (None, None, None,     │              0 │ yolo_v8_head_3_class_… │
# │ (Activation)              │ 128)                   │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ yolo_v8_head_1_box_1      │ (None, None, None, 64) │              0 │ yolo_v8_head_1_box_1_… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ yolo_v8_head_1_class_2_p… │ (None, None, None,     │              0 │ yolo_v8_head_1_class_… │
# │ (ZeroPadding2D)           │ 128)                   │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ yolo_v8_head_2_box_1      │ (None, None, None, 64) │              0 │ yolo_v8_head_2_box_1_… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ yolo_v8_head_2_class_2_p… │ (None, None, None,     │              0 │ yolo_v8_head_2_class_… │
# │ (ZeroPadding2D)           │ 128)                   │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ yolo_v8_head_3_box_1      │ (None, None, None, 64) │              0 │ yolo_v8_head_3_box_1_… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ yolo_v8_head_3_class_2_p… │ (None, None, None,     │              0 │ yolo_v8_head_3_class_… │
# │ (ZeroPadding2D)           │ 128)                   │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ yolo_v8_head_1_box_2_pad  │ (None, None, None, 64) │              0 │ yolo_v8_head_1_box_1[… │
# │ (ZeroPadding2D)           │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ yolo_v8_head_1_class_2_c… │ (None, None, None,     │        147,456 │ yolo_v8_head_1_class_… │
# │ (Conv2D)                  │ 128)                   │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ yolo_v8_head_2_box_2_pad  │ (None, None, None, 64) │              0 │ yolo_v8_head_2_box_1[… │
# │ (ZeroPadding2D)           │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ yolo_v8_head_2_class_2_c… │ (None, None, None,     │        147,456 │ yolo_v8_head_2_class_… │
# │ (Conv2D)                  │ 128)                   │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ yolo_v8_head_3_box_2_pad  │ (None, None, None, 64) │              0 │ yolo_v8_head_3_box_1[… │
# │ (ZeroPadding2D)           │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ yolo_v8_head_3_class_2_c… │ (None, None, None,     │        147,456 │ yolo_v8_head_3_class_… │
# │ (Conv2D)                  │ 128)                   │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ yolo_v8_head_1_box_2_conv │ (None, None, None, 64) │         36,864 │ yolo_v8_head_1_box_2_… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ yolo_v8_head_1_class_2_bn │ (None, None, None,     │            512 │ yolo_v8_head_1_class_… │
# │ (BatchNormalization)      │ 128)                   │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ yolo_v8_head_2_box_2_conv │ (None, None, None, 64) │         36,864 │ yolo_v8_head_2_box_2_… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ yolo_v8_head_2_class_2_bn │ (None, None, None,     │            512 │ yolo_v8_head_2_class_… │
# │ (BatchNormalization)      │ 128)                   │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ yolo_v8_head_3_box_2_conv │ (None, None, None, 64) │         36,864 │ yolo_v8_head_3_box_2_… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ yolo_v8_head_3_class_2_bn │ (None, None, None,     │            512 │ yolo_v8_head_3_class_… │
# │ (BatchNormalization)      │ 128)                   │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ yolo_v8_head_1_box_2_bn   │ (None, None, None, 64) │            256 │ yolo_v8_head_1_box_2_… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ yolo_v8_head_1_class_2    │ (None, None, None,     │              0 │ yolo_v8_head_1_class_… │
# │ (Activation)              │ 128)                   │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ yolo_v8_head_2_box_2_bn   │ (None, None, None, 64) │            256 │ yolo_v8_head_2_box_2_… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ yolo_v8_head_2_class_2    │ (None, None, None,     │              0 │ yolo_v8_head_2_class_… │
# │ (Activation)              │ 128)                   │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ yolo_v8_head_3_box_2_bn   │ (None, None, None, 64) │            256 │ yolo_v8_head_3_box_2_… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ yolo_v8_head_3_class_2    │ (None, None, None,     │              0 │ yolo_v8_head_3_class_… │
# │ (Activation)              │ 128)                   │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ yolo_v8_head_1_box_2      │ (None, None, None, 64) │              0 │ yolo_v8_head_1_box_2_… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ yolo_v8_head_1_class_3_c… │ (None, None, None, 30) │          3,870 │ yolo_v8_head_1_class_… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ yolo_v8_head_2_box_2      │ (None, None, None, 64) │              0 │ yolo_v8_head_2_box_2_… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ yolo_v8_head_2_class_3_c… │ (None, None, None, 30) │          3,870 │ yolo_v8_head_2_class_… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ yolo_v8_head_3_box_2      │ (None, None, None, 64) │              0 │ yolo_v8_head_3_box_2_… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ yolo_v8_head_3_class_3_c… │ (None, None, None, 30) │          3,870 │ yolo_v8_head_3_class_… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ yolo_v8_head_1_box_3_conv │ (None, None, None, 64) │          4,160 │ yolo_v8_head_1_box_2[… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ yolo_v8_head_1_classifier │ (None, None, None, 30) │              0 │ yolo_v8_head_1_class_… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ yolo_v8_head_2_box_3_conv │ (None, None, None, 64) │          4,160 │ yolo_v8_head_2_box_2[… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ yolo_v8_head_2_classifier │ (None, None, None, 30) │              0 │ yolo_v8_head_2_class_… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ yolo_v8_head_3_box_3_conv │ (None, None, None, 64) │          4,160 │ yolo_v8_head_3_box_2[… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ yolo_v8_head_3_classifier │ (None, None, None, 30) │              0 │ yolo_v8_head_3_class_… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_30            │ (None, None, None, 94) │              0 │ yolo_v8_head_1_box_3_… │
# │ (Concatenate)             │                        │                │ yolo_v8_head_1_classi… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_31            │ (None, None, None, 94) │              0 │ yolo_v8_head_2_box_3_… │
# │ (Concatenate)             │                        │                │ yolo_v8_head_2_classi… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_32            │ (None, None, None, 94) │              0 │ yolo_v8_head_3_box_3_… │
# │ (Concatenate)             │                        │                │ yolo_v8_head_3_classi… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ yolo_v8_head_1_output_re… │ (None, None, 94)       │              0 │ concatenate_30[0][0]   │
# │ (Reshape)                 │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ yolo_v8_head_2_output_re… │ (None, None, 94)       │              0 │ concatenate_31[0][0]   │
# │ (Reshape)                 │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ yolo_v8_head_3_output_re… │ (None, None, 94)       │              0 │ concatenate_32[0][0]   │
# │ (Reshape)                 │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_33            │ (None, None, 94)       │              0 │ yolo_v8_head_1_output… │
# │ (Concatenate)             │                        │                │ yolo_v8_head_2_output… │
# │                           │                        │                │ yolo_v8_head_3_output… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ box_outputs (Activation)  │ (None, None, 94)       │              0 │ concatenate_33[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ get_item_3 (GetItem)      │ (None, None, 30)       │              0 │ box_outputs[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ class (Concatenate)       │ (None, None, 30)       │              0 │ get_item_3[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ expand_dims_layer_1       │ (None, 1, None, 30)    │              0 │ class[0][0]            │
# │ (ExpandDimsLayer)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ global_average_pooling2d… │ (None, 30)             │              0 │ expand_dims_layer_1[0… │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_3 (Dense)           │ (None, 512)            │         15,872 │ global_average_poolin… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_4 (Dense)           │ (None, 256)            │        131,328 │ dense_3[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_5 (Dense)           │ (None, 30)             │          7,710 │ dense_4[0][0]          │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 13,374,744 (51.02 MB)
#  Trainable params: 13,352,408 (50.94 MB)
#  Non-trainable params: 22,336 (87.25 KB)

# %%
custom_model.compile(
    optimizer=keras.optimizers.Adam(learning_rate=0.001),
    loss="sparse_categorical_crossentropy",  # Loss untuk klasifikasi
    metrics=["accuracy"]
)

# %%
import os

# Periksa apakah file TFRecord ada
print(os.listdir(Tf_record_dir))
# Out:
# ['dataset.tfrecord']

# %%
custom_model.fit(
    train_dataset,
    validation_data=val_dataset,
    epochs=10,
    verbose=1
)
# Out:
# Epoch 1/10
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# <ipython-input-71-7eb09a4f8b1c> in <cell line: 1>()
# ----> 1 custom_model.fit(
#       2     train_dataset,
#       3     validation_data=val_dataset,
#       4     epochs=10,
#       5     verbose=1
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#     120             # To get the full stack trace, call:
#     121             # `keras.config.disable_traceback_filtering()`
# --> 122             raise e.with_traceback(filtered_tb) from None
#     123         finally:
#     124             del filtered_tb
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51   try:
#      52     ctx.ensure_initialized()
# ---> 53     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                         inputs, attrs, num_outputs)
#      55   except core._NotOkStatusException as e:
#
# NotFoundError: Graph execution error:
#
# Detected at node IteratorGetNext defined at (most recent call last):
#   File "/usr/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#
#   File "/usr/lib/python3.10/runpy.py", line 86, in _run_code
#
#   File "/usr/local/lib/python3.10/dist-packages/colab_kernel_launcher.py", line 37, in <module>
#
#   File "/usr/local/lib/python3.10/dist-packages/traitlets/config/application.py", line 992, in launch_instance
#
#   File "/usr/local/lib/python3.10/dist-packages/ipykernel/kernelapp.py", line 619, in start
#
#   File "/usr/local/lib/python3.10/dist-packages/tornado/platform/asyncio.py", line 195, in start
#
#   File "/usr/lib/python3.10/asyncio/base_events.py", line 603, in run_forever
#
#   File "/usr/lib/python3.10/asyncio/base_events.py", line 1909, in _run_once
#
#   File "/usr/lib/python3.10/asyncio/events.py", line 80, in _run
#
#   File "/usr/local/lib/python3.10/dist-packages/tornado/ioloop.py", line 685, in <lambda>
#
#   File "/usr/local/lib/python3.10/dist-packages/tornado/ioloop.py", line 738, in _run_callback
#
#   File "/usr/local/lib/python3.10/dist-packages/tornado/gen.py", line 825, in inner
#
#   File "/usr/local/lib/python3.10/dist-packages/tornado/gen.py", line 786, in run
#
#   File "/usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py", line 361, in process_one
#
#   File "/usr/local/lib/python3.10/dist-packages/tornado/gen.py", line 234, in wrapper
#
#   File "/usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py", line 261, in dispatch_shell
#
#   File "/usr/local/lib/python3.10/dist-packages/tornado/gen.py", line 234, in wrapper
#
#   File "/usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py", line 539, in execute_request
#
#   File "/usr/local/lib/python3.10/dist-packages/tornado/gen.py", line 234, in wrapper
#
#   File "/usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py", line 302, in do_execute
#
#   File "/usr/local/lib/python3.10/dist-packages/ipykernel/zmqshell.py", line 539, in run_cell
#
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2975, in run_cell
#
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3030, in _run_cell
#
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/async_helpers.py", line 78, in _pseudo_sync_runner
#
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3257, in run_cell_async
#
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3473, in run_ast_nodes
#
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#
#   File "<ipython-input-71-7eb09a4f8b1c>", line 1, in <cell line: 1>
#
#   File "/usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py", line 117, in error_handler
#
#   File "/usr/local/lib/python3.10/dist-packages/keras/src/backend/tensorflow/trainer.py", line 320, in fit
#
#   File "/usr/local/lib/python3.10/dist-packages/keras/src/backend/tensorflow/trainer.py", line 120, in one_step_on_iterator
#
# /content/dataset/ML_ObjectDetectionModelSmall/tf_record/train.tfrecord; No such file or directory
# 	 [[{{node IteratorGetNext}}]] [Op:__inference_one_step_on_iterator_330823]

# %%
model.save("yolo_rasadahana.h5")

# Simpan model ke dalam format JSON
model_json = model.to_json()
with open("yolo_rasadahana.json", "w") as json_file:
    json_file.write(model_json)

# %%
def get_predicted_labels(image, model, class_names):
    """
    Menghasilkan label kelas berdasarkan hasil prediksi dan bounding box.
    """
    predictions = model.predict(tf.expand_dims(image, axis=0))  # Prediksi untuk 1 gambar
    pred_boxes, pred_scores, pred_classes = predictions[0]

    predicted_labels = []
    for i in range(len(pred_boxes)):
        if pred_scores[i] > 0.5:  # Ambil hanya prediksi dengan score > threshold
            class_id = int(pred_classes[i])
            predicted_labels.append(class_names[class_id])

    return predicted_labels

# %%
test_image_path = 'path_to_test_image.jpg'  # Ganti dengan path gambar uji
test_image = tf.io.read_file(test_image_path)
test_image = tf.image.decode_jpeg(test_image, channels=3)
test_image = tf.image.resize(test_image, (416, 416)) / 255.0

# Menggunakan model untuk mendapatkan label dari gambar uji
predicted_labels = get_predicted_labels(test_image, model, class_names)
print(f"Predicted labels: {predicted_labels}")
